# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import pyodbc
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import re
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', 500)
sns.set()

# %%
# Connect to Access Database and access data with SQL commands
access_database = r'C:\Users\thwhi\Dropbox\Personal\Programming\Aircraft Stuff\avall_full_aircraft_crash_database\avall.mdb'
driver = r'Microsoft Access Driver (*.mdb, *.accdb)'
conn = pyodbc.connect(r'DRIVER={' + driver + '};DBQ=' + access_database + ';')

# %%
# Import data dictionary which has what the different codes in cells actually
# mean. The ct_iaids also contains similar coding information

df_data_dictionary = pd.read_sql_query('SELECT * FROM eADMSPUB_DataDictionary',conn)
df_ct_iaids = pd.read_sql_query('SELECT * FROM ct_iaids',conn)

# %%
# Import several of the important tables. For now I just imported the whole table, but in the future
# I might select a subset of variables to look at. Without knowing quite which variables are 
# important, I decided to have them all available for ease of analysis. 
df_events = pd.read_sql_query('SELECT * FROM events',conn)
df_aircraft = pd.read_sql_query('SELECT * FROM aircraft',conn)
df_engines = pd.read_sql_query('SELECT * FROM engines',conn)
df_flight_crew = pd.read_sql_query('SELECT * FROM Flight_Crew',conn)
df_flight_time = pd.read_sql_query('SELECT * FROM flight_time',conn)
df_findings = pd.read_sql_query('SELECT * FROM Findings',conn)
df_occurrences = pd.read_sql_query('SELECT * FROM OCCURRENCES',conn)

# %%
# Function to remove duplicates, set all values to uppercase, and to strip all entries of leading and trailing spaces
def strip_strings(df):
    df = df.loc[:,~df.columns.duplicated()]
    df = df.dropna(axis=1,how='all')
    for col in df.columns:
        if df[col].dtype=='O':
            df[col] = df[col].str.strip()
        if df[col].dtype=='O':
            df[col] = df[col].str.upper()
    return(df)

# %%
# Apply that function to each of the tables from that database
df_events = strip_strings(df_events)
df_aircraft = strip_strings(df_aircraft)
df_engines = strip_strings(df_engines)
df_flight_crew = strip_strings(df_flight_crew)
df_flight_time = strip_strings(df_flight_time)
df_findings = strip_strings(df_findings)
df_occurrences = strip_strings(df_occurrences)

# %%
# Remove any non-GA records from the events table. This will trickle down to all the other tables which always use
# df_events.
ga_far_parts = ['091','091K','125','133','137']
df_events = df_events.merge(df_aircraft[['ev_id','far_part']],how='left',left_on='ev_id',right_on='ev_id')
df_events = df_events[df_events['far_part'].isin(ga_far_parts)]

# %%
# Set total flight hours values listed as above 95000 to NaN, as they are almost certainly mis-entries
df_flight_time['flight_hours'] = df_flight_time['flight_hours'].apply(lambda x: np.nan if x > 95000 else x)

# %%
# Function to merge dfs in the most common fashion
def merge_dfs(df2,field):
    df = df_events[['ev_id','ev_highest_injury']].merge(df2[['ev_id',field]],how='left',left_on='ev_id',right_on='ev_id')
    return(df)

# %%
# Function to plot the most common type of comparison I'm doing in this analysis
def plot_ratio_by_field(df,field,name,sort=False):

    df_rate = df.groupby([field,'ev_highest_injury']).size().unstack(fill_value=0)
    df_rate['TOTL'] = df_rate.sum(axis=1)
    df_rate['FATL_Ratio'] = df_rate['FATL']/df_rate['TOTL']
    if sort:
        df_rate = df_rate.sort_values('FATL_Ratio',ascending=False)

    fig,ax = plt.subplots()
    fig.set_size_inches(8,6)
    df_rate['FATL_Ratio'].plot.bar(ax=ax)
    ax.set_title('Ratio of Fatal Accidents to Total Accidents by {}\n1982 - Present'.format(name),fontsize=16)
    ax.set_ylabel('Ratio',fontsize=14)
    ax.set_xlabel(name,fontsize=14)
    a=ax.set_xticklabels(df_rate.index,rotation=0)
    
    return(fig,ax)

# %%
df = merge_dfs(df_aircraft,'num_eng')
fig,ax = plot_ratio_by_field(df,'num_eng','Number of Engines',sort=True)

# %%
df.head()
# Out:
#             ev_id ev_highest_injury  num_eng
# 0  20001208X07734              FATL      1.0
# 1  20021008X05297              SERS      1.0
# 2  20040127X00111              NONE      1.0
# 3  20181125X85246              NONE      1.0
# 4  20001213X34369              NONE      1.0

# %%
df_aircraft.head()
# Out:
#             ev_id  Aircraft_Key regis_no     ntsb_no acft_missing far_part  \
# 0  20001208X07734             1   N6172C  LAX97FA143            N      091
# 1  20021008X05297             1   N9714W  CHI02LA299         None      091
# 2  20040127X00111             1   N7127V  LAX04LA103         None      091
# 3  20181125X85246             1   N66710  GAA19CA073         None      091
# 4  20001213X34369             1   N70021  ANC86LA135            N      091
#
#   flt_plan_filed flight_plan_activated damage acft_fire acft_expl acft_make  \
# 0            IFR                  None   DEST      NONE      NONE    CESSNA
# 1           NONE                     N   SUBS      NONE      NONE     PIPER
# 2            VFR                     Y   SUBS      NONE      NONE    MOONEY
# 3           NONE                     U   SUBS      NONE      NONE     BEECH
# 4           NONE                  None   SUBS      NONE      NONE    CESSNA
#
#   acft_model acft_series acft_serial_no  cert_max_gr_wt acft_category  \
# 0      T210N       T210N      210-63820          3800.0           AIR
# 1  PA-28-140        None       28-23190          2150.0           AIR
# 2        20F        None        22-0056          2740.0           AIR
# 3        C23        None         M-2387          2450.0           AIR
# 4     A-185E      A-185E       18501896          3300.0           AIR
#
#   acft_reg_cls homebuilt  fc_seats  cc_seats  pax_seats  total_seats  num_eng  \
# 0         USUS         N       NaN       NaN        NaN          6.0      1.0
# 1         USUS         N       NaN       NaN        NaN          4.0      1.0
# 2         USUS         N       NaN       NaN        NaN          4.0      1.0
# 3         None         N       2.0       NaN        2.0          4.0      1.0
# 4         USUS         N       NaN       NaN        NaN          6.0      1.0
#
#   fixed_retractable type_last_insp date_last_insp  afm_hrs_last_insp  afm_hrs  \
# 0              RETR           ANNL     1996-11-16               34.0   1643.0
# 1              None           None            NaT                NaN   4700.0
# 2              RETR           ANNL     2003-01-10              120.0   4120.0
# 3              None           ANNL     2017-11-20                NaN   6109.0
# 4              None            UNK            NaT                NaN    962.0
#
#   elt_install elt_oper elt_aided_loc_ev elt_type  \
# 0           Y        U                U     None
# 1           Y        U                N     None
# 2           Y        N                N     None
# 3           Y        N                U      C91
# 4           Y        N                N     None
#
#                             owner_acft           owner_street    owner_city  \
# 0                    JAMES E. ELDREDGE  4039 KNOLL RIDGE AVE.     LAS VEGAS
# 1             WEST CENTRAL AIRWAYS INC     4005 HIGHWAY 210 W  FERGUS FALLS
# 2                        THOMAS CHENAL                   None    SCOTTSDALE
# 3  DONALD UTTENREITHER, RICKEY COOKSEY                   None   PORTERVILLE
# 4                       LARRY D. GRANT        P.O. BOX 772694   EAGLE RIVER
#
#   owner_state owner_country  owner_zip oper_individual_name       oper_name  \
# 0          NV                    89030                 None
# 1          MN           USA      56537                    N            None
# 2          AZ           USA      85254                    N            None
# 3          CA           USA  932579130                    Y  RICKEY COOKSEY
# 4          AK                    99577                 None
#
#   oper_same            oper_dba oper_addr_same oper_street    oper_city  \
# 0         Y  RANGER ENTERPRISES              Y
# 1         Y                None              Y        None         None
# 2         Y                None              Y        None         None
# 3         N                None              Y        None  PORTERVILLE
# 4         Y                                  Y
#
#   oper_state oper_country   oper_zip oper_code certs_held oprtng_cert  \
# 0                                                       N           N
# 1       None         None       None      IIQA          N        None
# 2       None         None       None      None          N        None
# 3         CA          USA  932579130      None          Y        None
# 4                                                       N           N
#
#   oper_cert oper_cert_num oper_sched oper_dom_int oper_pax_cargo type_fly  \
# 0       UNK          None       None         None           None     PERS
# 1      None          None       None         None           None     INST
# 2      None          None       None         None           None     PERS
# 3      None          None       None         None           None     PERS
# 4       UNK          None       None         None           None     PERS
#
#   second_pilot dprt_pt_same_ev dprt_apt_id    dprt_city dprt_state  \
# 0            N               N         LVS    LAS VEGAS         NM
# 1            Y               N         04Y       HAWLEY         MN
# 2            N               N         SFA     SANTA FE         NM
# 3            N               N         PTV  PORTERVILLE         CA
# 4            N               N         MRI    ANCHORAGE         AK
#
#   dprt_country  dprt_time dprt_timezn dest_same_local dest_apt_id  \
# 0                  1750.0         MST            LOCL         VGT
# 1          USA     2045.0         CDT            SAME         JKJ
# 2          USA     1500.0         CST            SAME         SDL
# 3          USA     1250.0         PST            LOCL         PTV
# 4                  1000.0         ADT            None
#
#          dest_city dest_state dest_country  phase_flt_spec report_to_icao  \
# 0                          NV                        540.0           None
# 1        MOOREHEAD         MN          USA           570.0           None
# 2       SCOTTSDALE         AZ          USA           570.0              N
# 3      PORTERVILLE         CA          USA             NaN           None
# 4  CHICKLOON RIVER         AK                        570.0           None
#
#   evacuation           lchg_date lchg_userid afm_hrs_since rwy_num  rwy_len  \
# 0       None 2001-01-02 10:34:39         DBO          None       0      NaN
# 1          N 2003-03-13 11:39:24        SULP          ACCI      12   4000.0
# 2          N                 NaT        None          ACCI      21   8251.0
# 3       None 2018-12-21 17:23:10        GUTE          INSP      30   5960.0
# 4       None 2001-01-02 10:36:05         DBO          None       0      0.0
#
#    rwy_width site_seeing air_medical med_type_flight  acft_year  \
# 0        NaN           N           N            None        NaN
# 1       75.0           N           N            None        NaN
# 2       75.0           N           N            None        NaN
# 3      150.0           N           N            None     1983.0
# 4        0.0           N           N            None        NaN
#
#    commercial_space_flight  unmanned  ifr_equipped_cert  elt_mounted_aircraft  \
# 0                    False     False              False                 False
# 1                    False     False              False                 False
# 2                    False     False              False                 False
# 3                    False     False              False                 False
# 4                    False     False              False                 False
#
#    elt_connected_antenna
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %%
df_avdata = pd.read_csv(r'Files\AviationData.txt',delimiter='|')

# %%
df_avdata.sample(20)
# Out:
#              Event Id   Investigation Type   Accident Number    Event Date   \
# 56042  20001212X24712             Accident        ANC91LA016    12/09/1990
# 78104  20001214X43238             Incident        CHI83IA263    06/16/1983
# 16305  20090727X90529             Accident        CEN09CA464    07/20/2009
# 24222  20050718X01043             Accident        SEA05CA132    06/25/2005
# 80310  20020917X04423             Incident       CHI82IA364B    09/23/1982
# 39191  20001211X10025             Accident        CHI98LA173    05/24/1998
# 56704  20001212X23893             Accident        ATL90LA162    08/26/1990
# 70205  20001214X37761             Accident        DEN85FA240    09/12/1985
# 56086  20001212X24666             Accident        MIA91LA037    11/29/1990
# 64137  20001213X32453             Accident        SEA88LA013    10/25/1987
# 39303  20001211X10007             Accident        CHI98LA147    05/11/1998
# 16929  20090413X62630             Incident        ERA09IA240    04/12/2009
# 2875   20170712X12448             Accident        DCA17LA182    07/02/2017
# 41814  20001208X07523             Incident        FTW97IA119    03/10/1997
# 67998  20001213X34214             Accident        LAX86LA277    07/02/1986
# 8788   20140131X95050             Incident        ENG13WA044    09/07/2013
# 54023  20001212X18173             Accident        NYC91LA242    09/21/1991
# 80562  20020917X04422             Incident        CHI82IA331    09/01/1982
# 59259  20001213X29170             Accident       LAX89LA291A    08/30/1989
# 24116  20050714X01022             Accident        NYC05LA116    07/07/2005
#
#                    Location          Country     Latitude      Longitude   \
# 56042         FAIRBANKS, AK    United States
# 78104         CHARLOTTE, NC    United States
# 16305      Fort Collins, CO    United States    40.451111    -105.006667
# 24222             Teton, ID    United States    43.888055    -111.668611
# 80310           PONTIAC, MI    United States
# 39191           AUGUSTA, KS    United States
# 56704          SAVANNAH, TN    United States
# 70205      FORT COLLINS, CO    United States
# 56086        FORT WHITE, FL    United States
# 64137   SNOQUALAMIE PSS, WA    United States
# 39303          HANNIBAL, MO    United States
# 16929        Fort Myers, FL    United States    26.536111     -81.755278
# 2875             Denver, CO    United States
# 41814       DFW AIRPORT, TX    United States
# 67998       GARBERVILLE, CA    United States
# 8788         Moscow, Russia           Russia
# 54023            VESTAL, NY    United States
# 80562          APPLETON, WI    United States
# 59259             HEMET, CA    United States
# 24116            Medina, OH    United States    41.131389     -81.765000
#
#        Airport Code                     Airport Name   Injury Severity   \
# 56042           EIL                      EIELSON AFB         Non-Fatal
# 78104           ORD                           O'HARE          Incident
# 16305           FNL    Fort Collins-Loveland AIrport         Non-Fatal
# 24222                                                        Non-Fatal
# 80310           PTK                  OAKLAND-PONTIAC          Incident
# 39191           3AU                AUGUSTA MUNICIPAL         Non-Fatal
# 56704           SNH                    HARDIN COUNTY         Non-Fatal
# 70205                                                         Fatal(1)
# 56086                                                        Non-Fatal
# 64137                                                        Non-Fatal
# 39303           HAE               HANNIBAL MUNICIPAL         Non-Fatal
# 16929           RSW          Southwest Florida Int'l          Incident
# 2875                                             DEN         Non-Fatal
# 41814           DFW                DFW INTERNATIONAL          Incident
# 67998                                    GARBERVILLE         Non-Fatal
# 8788                                                          Incident
# 54023                                                        Non-Fatal
# 80562           ATW                OUTAGAMIE CO. A/P          Incident
# 59259           HMT                       HEMET-RYAN         Non-Fatal
# 24116           1G5         Medina Municipal Airport         Non-Fatal
#
#        Aircraft Damage   Aircraft Category   Registration Number   \
# 56042      Substantial                                    N3809Y
# 78104            Minor                                     N782N
# 16305      Substantial            Airplane                N8778D
# 24222      Substantial            Airplane                N2021V
# 80310            Minor            Airplane                N4745B
# 39191      Substantial                                    N5247J
# 56704      Substantial                                     N60DF
# 70205        Destroyed                                    N45724
# 56086      Substantial                                    N45360
# 64137        Destroyed                                    N44856
# 39303      Substantial                                    N733HY
# 16929                             Airplane                N559DW
# 2875       Substantial            Airplane                N796SK
# 41814            Minor                                    N909PG
# 67998      Substantial                                    N26186
# 8788                              Airplane
# 54023      Substantial                                     N4110
# 80562            Minor            Airplane                 N261S
# 59259        Destroyed                                    N65843
# 24116      Substantial                                    N318RF
#
#                   Make          Model   Amateur Built   Number of Engines   \
# 56042            BEECH          BE-77              No                   1
# 78104           BOEING        737-201              No                   2
# 16305            PIPER      PA-22-160              No                   1
# 24222        Weatherly           620B              No                   1
# 80310           CESSNA            152              No                   1
# 39191           Cessna           310R              No                   2
# 56704    I.C.A. Brasov        IS-28B2              No                   0
# 70205   AERO COMMANDER          680FL              No                   2
# 56086           CESSNA           150M              No                   1
# 64137            PIPER      PA-28-161              No                   1
# 39303           Cessna           172N              No                   1
# 16929            BEECH           B200              No                   2
# 2875    BOMBARDIER INC    CL 600 2C10                                   2
# 41814           Boeing        727-2K5              No                   3
# 67998           HILLER         UH-12C              No                   1
# 8788        BOMBARDIER     CL600 2B19              No                   2
# 54023           CESSNA           180L              No                   1
# 80562       SWEARINGEN       SA-226TC              No                   2
# 59259        SCHWEIZER      SGS 2-33A              No
# 24116           Cessna           421B              No                   2
#
#           Engine Type              FAR Description   Schedule   \
# 56042   Reciprocating
# 78104       Turbo Jet                                    SCHD
# 16305   Reciprocating    Part 91: General Aviation
# 24222   Reciprocating       Part 137: Agricultural
# 80310   Reciprocating    Part 91: General Aviation
# 39191   Reciprocating
# 56704         Unknown
# 70205   Reciprocating                                    NSCH
# 56086   Reciprocating
# 64137   Reciprocating
# 39303   Reciprocating
# 16929      Turbo Prop    Part 91: General Aviation
# 2875        Turbo Fan        Part 121: Air Carrier       SCHD
# 41814       Turbo Fan                                    NSCH
# 67998   Reciprocating
# 8788        Turbo Fan
# 54023   Reciprocating
# 80562      Turbo Prop    Part 91: General Aviation
# 59259         Unknown
# 24116   Reciprocating
#
#          Purpose of Flight                  Air Carrier   \
# 56042             Personal
# 78104              Unknown
# 16305             Personal
# 24222   Aerial Application
# 80310             Personal
# 39191             Personal
# 56704             Personal
# 70205              Unknown    (DBA: AIR PARCEL EXPRESS)
# 56086             Personal
# 64137             Personal
# 39303             Personal
# 16929             Personal
# 2875                               SKYWEST AIRLINES INC
# 41814              Unknown                 AEROMEXPRESS
# 67998        Instructional
# 8788
# 54023             Personal
# 80562              Unknown
# 59259             Personal
# 24116             Business
#
#        Total Fatal Injuries   Total Serious Injuries   Total Minor Injuries   \
# 56042                     0                        0                      0
# 78104                     0                        0                      0
# 16305
# 24222
# 80310                     0                        0                      0
# 39191                     0                        4                      0
# 56704                     0                        1                      1
# 70205                     1                        0                      0
# 56086                     0                        0                      0
# 64137                     0                        0                      1
# 39303                     0                        0                      1
# 16929                     1
# 2875
# 41814                     0                        0                      0
# 67998                     0                        0                      0
# 8788
# 54023                     0                        0                      0
# 80562                     0                        0                      0
# 59259                     0                        0                      2
# 24116
#
#        Total Uninjured   Weather Condition   Broad Phase of Flight   \
# 56042                2                 VMC                    TAXI
# 78104              102                 IMC                   CLIMB
# 16305                1                 VMC                 LANDING
# 24222                1                 VMC             MANEUVERING
# 80310                3                 VMC                 TAKEOFF
# 39191                0                 VMC                 TAKEOFF
# 56704                0                 VMC                 LANDING
# 70205                0                 VMC                   CLIMB
# 56086                2                 VMC                 LANDING
# 64137                0                 IMC                  CRUISE
# 39303                0                 VMC                 TAKEOFF
# 16929                4                 VMC                   CLIMB
# 2875                59                 VMC                 LANDING
# 41814                4                 VMC                 TAKEOFF
# 67998                1                 VMC                  CRUISE
# 8788                10
# 54023                1                 VMC                  CRUISE
# 80562                2                 VMC                 TAKEOFF
# 59259                1                 VMC                 TAKEOFF
# 24116                4                 VMC                 LANDING
#
#          Report Status   Publication Date
# 56042   Probable Cause         10/02/1992
# 78104   Probable Cause
# 16305   Probable Cause         07/26/2010
# 24222   Probable Cause         10/27/2005
# 80310   Probable Cause         09/23/1983
# 39191   Probable Cause         05/19/1999
# 56704   Probable Cause         12/14/1992
# 70205   Probable Cause
# 56086   Probable Cause         12/08/1992
# 64137   Probable Cause         12/27/1988
# 39303   Probable Cause         02/15/2001
# 16929   Probable Cause         04/19/2010
# 2875       Preliminary         05/17/2019
# 41814   Probable Cause         04/24/1998
# 67998   Probable Cause
# 8788           Foreign         02/04/2014
# 54023   Probable Cause         05/03/1993
# 80562   Probable Cause         09/01/1983
# 59259   Probable Cause         09/30/1992
# 24116   Probable Cause         04/25/2006

# %%
df_avdata.columns
# Out:
# Index(['Event Id ', ' Investigation Type ', ' Accident Number ',
#        ' Event Date ', ' Location ', ' Country ', ' Latitude ', ' Longitude ',
#        ' Airport Code ', ' Airport Name ', ' Injury Severity ',
#        ' Aircraft Damage ', ' Aircraft Category ', ' Registration Number ',
#        ' Make ', ' Model ', ' Amateur Built ', ' Number of Engines ',
#        ' Engine Type ', ' FAR Description ', ' Schedule ',
#        ' Purpose of Flight ', ' Air Carrier ', ' Total Fatal Injuries ',
#        ' Total Serious Injuries ', ' Total Minor Injuries ',
#        ' Total Uninjured ', ' Weather Condition ', ' Broad Phase of Flight ',
#        ' Report Status ', ' Publication Date ', ' '],
#       dtype='object')

# %%
df_avdata = strip_strings(df_avdata)

# %%
df_avdata.columns = df_avdata.columns.str.strip()

# %%
df_avdata = df_avdata.rename(columns = {'Event Id':'ev_id'})

# %%
df_phase_of_flight = merge_dfs(df_avdata,'Broad Phase of Flight')

# %%
df_phase_of_flight.head()
# Out:
#             ev_id ev_highest_injury Broad Phase of Flight
# 0  20001208X07734              FATL                CRUISE
# 1  20021008X05297              SERS              APPROACH
# 2  20040127X00111              NONE               LANDING
# 3  20181125X85246              NONE               LANDING
# 4  20001213X34369              NONE               LANDING

# %%
df_phase_of_flight['Broad Phase of Flight'].value_counts()
# Out:
# LANDING        19185
# TAKEOFF        14730
# CRUISE         10002
# MANEUVERING     9892
# APPROACH        7504
#                 3102
# TAXI            2131
# CLIMB           2016
# DESCENT         1939
# GO-AROUND       1602
# STANDING        1062
# UNKNOWN          588
# OTHER            141
# Name: Broad Phase of Flight, dtype: int64

# %%
df_phase_of_flight['Broad Phase of Flight'].replace('','UNKNOWN',inplace=True)

# %%
fig,ax = plot_ratio_by_field(df_phase_of_flight,'Broad Phase of Flight','Broad Phase of Flight',sort=True)
a = ax.set_xticklabels(ax.get_xticklabels(),rotation=45,ha='right')

# %%
df_findings.head()
# Out:
#             ev_id  Aircraft_Key  finding_no finding_code  \
# 0  20120214X84853             1           1   0106203711
# 1  20120214X84853             1           2   0204101544
# 2  20081003X65757             1           1   0106202020
# 3  20081003X65757             1           2   0206304046
# 4  20110716X12058             1           1   0106202020
#
#                                  finding_description category_no  \
# 0  AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORM...          01
# 1  PERSONNEL ISSUES-ACTION/DECISION-ACTION-INCORR...          02
# 2  AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORM...          01
# 3  PERSONNEL ISSUES-TASK PERFORMANCE-USE OF EQUIP...          02
# 4  AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORM...          01
#
#   subcategory_no section_no subsection_no modifier_no Cause_Factor  \
# 0             06         20            37          11            C
# 1             04         10            15          44            C
# 2             06         20            20          20            C
# 3             06         30            40          46            C
# 4             06         20            20          20            C
#
#             lchg_date lchg_userid
# 0 2012-03-23 18:30:44        SNYG
# 1 2012-03-23 18:30:44        SNYG
# 2 2009-01-18 15:58:33        GROL
# 3 2009-01-18 15:58:33        GROL
# 4 2011-08-23 12:36:50        SCHL

# %%
df_findings['finding_description'].value_counts()
# Out:
# PERSONNEL ISSUES-TASK PERFORMANCE-USE OF EQUIP/INFO-AIRCRAFT CONTROL-PILOT - C                                                   4445
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORMANCE/CONTROL PARAMETERS-DIRECTIONAL CONTROL-NOT ATTAINED/MAINTAINED - C            2032
# NOT DETERMINED-NOT DETERMINED-(GENERAL)-(GENERAL)-UNKNOWN/NOT DETERMINED - C                                                     1310
# PERSONNEL ISSUES-ACTION/DECISION-INFO PROCESSING/DECISION-DECISION MAKING/JUDGMENT-PILOT - C                                     1201
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORMANCE/CONTROL PARAMETERS-AIRSPEED-NOT ATTAINED/MAINTAINED - C                        916
# PERSONNEL ISSUES-ACTION/DECISION-ACTION-INCORRECT ACTION PERFORMANCE-PILOT - C                                                    741
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORMANCE/CONTROL PARAMETERS-(GENERAL)-NOT ATTAINED/MAINTAINED - C                       716
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORMANCE/CONTROL PARAMETERS-ALTITUDE-NOT ATTAINED/MAINTAINED - C                        579
# PERSONNEL ISSUES-TASK PERFORMANCE-USE OF EQUIP/INFO-USE OF EQUIP/SYSTEM-PILOT - C                                                 468
# AIRCRAFT-FLUIDS/MISC HARDWARE-FLUIDS-FUEL-FLUID LEVEL - C                                                                         434
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORMANCE/CONTROL PARAMETERS-LANDING FLARE-NOT ATTAINED/MAINTAINED - C                   409
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORMANCE/CONTROL PARAMETERS-DESCENT/APPROACH/GLIDE PATH-NOT ATTAINED/MAINTAINED - C     375
# ENVIRONMENTAL ISSUES-PHYSICAL ENVIRONMENT-OBJECT/ANIMAL/SUBSTANCE-TREE(S)-CONTRIBUTED TO OUTCOME                                  354
# PERSONNEL ISSUES-PSYCHOLOGICAL-ATTENTION/MONITORING-MONITORING ENVIRONMENT-PILOT - C                                              351
# PERSONNEL ISSUES-TASK PERFORMANCE-PLANNING/PREPARATION-FUEL PLANNING-PILOT - C                                                    350
# AIRCRAFT-FLUIDS/MISC HARDWARE-FLUIDS-FUEL-FLUID MANAGEMENT - C                                                                    332
# PERSONNEL ISSUES-TASK PERFORMANCE-USE OF EQUIP/INFO-AIRCRAFT CONTROL-STUDENT/INSTRUCTED PILOT - C                                 319
# PERSONNEL ISSUES-ACTION/DECISION-ACTION-LACK OF ACTION-PILOT - C                                                                  310
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORMANCE/CONTROL PARAMETERS-LANDING FLARE-INCORRECT USE/OPERATION - C                   290
# PERSONNEL ISSUES-ACTION/DECISION-INFO PROCESSING/DECISION-DECISION MAKING/JUDGMENT-PILOT - F                                      269
# ENVIRONMENTAL ISSUES-CONDITIONS/WEATHER/PHENOMENA-WIND-GUSTS-EFFECT ON OPERATION                                                  263
# PERSONNEL ISSUES-TASK PERFORMANCE-USE OF EQUIP/INFO-AIRCRAFT CONTROL-STUDENT PILOT - C                                            214
# ENVIRONMENTAL ISSUES-CONDITIONS/WEATHER/PHENOMENA-WIND-CROSSWIND-EFFECT ON OPERATION                                              210
# PERSONNEL ISSUES-TASK PERFORMANCE-INSPECTION-PREFLIGHT INSPECTION-PILOT - C                                                       208
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORMANCE/CONTROL PARAMETERS-ANGLE OF ATTACK-NOT ATTAINED/MAINTAINED - C                 204
# PERSONNEL ISSUES-ACTION/DECISION-ACTION-DELAYED ACTION-INSTRUCTOR/CHECK PILOT - C                                                 202
# PERSONNEL ISSUES-ACTION/DECISION-ACTION-DELAYED ACTION-PILOT - C                                                                  195
# ENVIRONMENTAL ISSUES-PHYSICAL ENVIRONMENT-TERRAIN-ROUGH TERRAIN-CONTRIBUTED TO OUTCOME                                            189
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORMANCE/CONTROL PARAMETERS-PITCH CONTROL-NOT ATTAINED/MAINTAINED - C                   187
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORMANCE/CONTROL PARAMETERS-ANGLE OF ATTACK-CAPABILITY EXCEEDED - C                     174
#                                                                                                                                  ...
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-PERFORMANCE/CONTROL PARAMETERS-ANGLE OF ATTACK-NOT ATTAINED/MAINTAINED                       1
# PERSONNEL ISSUES-TASK PERFORMANCE-(GENERAL)-(GENERAL)-MAINTENANCE PERSONNEL - F                                                     1
# AIRCRAFT-AIRCRAFT SYSTEMS-LANDING GEAR SYSTEM-NOSE/TAIL GEAR ATTACH SECTION-NOT INSPECTED - F                                       1
# AIRCRAFT-AIRCRAFT SYSTEMS-FLIGHT CONTROL SYSTEM-(GENERAL)-DESIGN - F                                                                1
# AIRCRAFT-AIRCRAFT SYSTEMS-FUEL SYSTEM-FUEL TRANSFER VALVE-MALFUNCTION - C                                                           1
# AIRCRAFT-AIRCRAFT SYSTEMS-AUTO FLIGHT SYSTEM-AUTOPILOT COMPUTER-CAPABILITY EXCEEDED - F                                             1
# AIRCRAFT-AIRCRAFT STRUCTURES-WING STRUCTURE-SPOILERS-NOT USED/OPERATED - F                                                          1
# PERSONNEL ISSUES-TASK PERFORMANCE-USE OF EQUIP/INFO-USE OF AVAILABLE RESOURCES-FLIGHT CREW - F                                      1
# PERSONNEL ISSUES-ACTION/DECISION-ACTION-LACK OF ACTION-FLIGHT CREW                                                                  1
# PERSONNEL ISSUES-ACTION/DECISION-ACTION-LACK OF ACTION-PASSENGER - F                                                                1
# ENVIRONMENTAL ISSUES-CONDITIONS/WEATHER/PHENOMENA-TURBULENCE-CLEAR AIR TURBULENCE-EFFECT ON OPERATION                               1
# ENVIRONMENTAL ISSUES-PHYSICAL ENVIRONMENT-OBJECT/ANIMAL/SUBSTANCE-POLE-RESPONSE/COMPENSATION - F                                    1
# AIRCRAFT-AIRCRAFT SYSTEMS-ELECTRICAL POWER SYSTEM-(GENERAL)-INOPERATIVE                                                             1
# ENVIRONMENTAL ISSUES-TASK ENVIRONMENT-PHYSICAL WORKSPACE-VISIBILITY-EFFECT ON PERSONNEL - C                                         1
# PERSONNEL ISSUES-PSYCHOLOGICAL-PERSONALITY/ATTITUDE-SELF CONFIDENCE-PILOT - C                                                       1
# AIRCRAFT-AIRCRAFT STRUCTURES-WING STRUCTURE-PLATES/SKINS (ON WING)-DAMAGED/DEGRADED                                                 1
# PERSONNEL ISSUES-PSYCHOLOGICAL-COGNITIVE LIMITATION-(GENERAL)-PILOT - C                                                             1
# AIRCRAFT-AIRCRAFT SYSTEMS-FLIGHT CONTROL SYSTEM-CONTROL COLUMN SECTION-INADEQUATE INSPECTION - F                                    1
# ENVIRONMENTAL ISSUES-PHYSICAL ENVIRONMENT-OBJECT/ANIMAL/SUBSTANCE-DEBRIS/DIRT/FOREIGN OBJECT-AWARENESS OF CONDITION                 1
# AIRCRAFT-AIRCRAFT STRUCTURES-EMPENNAGE STRUCTURE-ELEVATORS-FAILURE - C                                                              1
# ENVIRONMENTAL ISSUES-CONDITIONS/WEATHER/PHENOMENA-TURBULENCE-WAKE TURBULENCE-AWARENESS OF CONDITION - F                             1
# AIRCRAFT-AIRCRAFT POWER PLANT-ENGINE (RECIPROCATING)-RECIP ENG CYL SECTION-DAMAGED/DEGRADED - F                                     1
# AIRCRAFT-AIRCRAFT STRUCTURES-FUSELAGE-GEAR ATTACH FITTINGS (ON FUS)-CAPABILITY EXCEEDED                                             1
# AIRCRAFT-AIRCRAFT STRUCTURES-FUSELAGE-SEAT/CARGO ATTACH FITTING-NOT INSPECTED                                                       1
# AIRCRAFT-AIRCRAFT OPER/PERF/CAPABILITY-AIRCRAFT CAPABILITY-INSTRUMENT FLIGHT CAPABILITY-ATTAIN/MAINTAIN NOT POSSIBLE                1
# AIRCRAFT-AIRCRAFT SYSTEMS-INDICATING/RECORDING SYSTEMS-INSTRUMENT PANEL   -MALFUNCTION - C                                          1
# AIRCRAFT-AIRCRAFT STRUCTURES-FUSELAGE-SEAT/CARGO ATTACH FITTING-FAILURE - C                                                         1
# PERSONNEL ISSUES-EXPERIENCE/KNOWLEDGE-TRAINING-TOTAL INSTRUCT/TRAINING RECVD-ATC PERSONNEL                                          1
# AIRCRAFT-AIRCRAFT STRUCTURES-WING STRUCTURE-SPOILERS-INOPERATIVE - C                                                                1
# ENVIRONMENTAL ISSUES-CONDITIONS/WEATHER/PHENOMENA-WIND-HIGH WIND-AWARENESS OF CONDITION - C                                         1
# Name: finding_description, Length: 5176, dtype: int64
